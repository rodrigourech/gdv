# %%
# ------------------------------
# Data Import & Preparation
# ------------------------------
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Quellen (GitHub Repository: MeteoSchweiz CH2018 Szenarien)
url_rcp45 = "https://raw.githubusercontent.com/rodrigourech/ivi/main/data/RCP45_tas.csv"
url_rcp85 = "https://raw.githubusercontent.com/rodrigourech/ivi/main/data/RCP85_tas.csv"

# CSVs einlesen (Best Practices: UTF-8 Encoding, parse_dates für Zeitspalten)
df_rcp45 = pd.read_csv(url_rcp45, parse_dates=["date"], encoding="utf-8-sig")
df_rcp85 = pd.read_csv(url_rcp85, parse_dates=["date"], encoding="utf-8-sig")

# Subsets für Performance-Tests (kleines vs. grosses Sample)
df_rcp45_small = df_rcp45.sample(n=3000, random_state=42).reset_index(drop=True)
df_rcp85_large = df_rcp85.sample(n=300000, random_state=42).reset_index(drop=True)

# Szenario-Label hinzufügen
df_rcp45_small["scenario"] = "RCP4.5"
df_rcp85_large["scenario"] = "RCP8.5"

# Zusammenführen
df = pd.concat([df_rcp45_small, df_rcp85_large], ignore_index=True)

# Jahr & Dekade extrahieren
df["year"] = df["date"].dt.year
df["decade"] = (df["year"] // 10) * 10

# ------------------------------
# Parameter
# ------------------------------
SELECT_SCENARIO = "RCP8.5"
stations_order  = ["Bern", "St. Gallen", "Sion"]  # gewünschte Stationen

# ------------------------------
# Aggregation: Dekadenmittel
# ------------------------------
df_decadal = (
    df.groupby(["decade", "station", "scenario"], as_index=False)["value"]
      .mean()
      .rename(columns={"value": "value_decade_mean"})
)

# Filter auf gewähltes Szenario & Stationen
decadal_plot = (
    df_decadal[(df_decadal["scenario"] == SELECT_SCENARIO) &
               (df_decadal["station"].isin(stations_order))]
    .copy()
)

# %%
# =========================================================
# Decadal Mean Temperature: Side-by-Side Bars
# =========================================================
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


SELECT_SCENARIO = "RCP8.5"  # oder "RCP4.5"
stations_order  = ["St. Gallen", "Bern", "Sion"]

# Daten für gewähltes Szenario + Stationen
decadal_plot = (
    df_decadal[df_decadal["scenario"] == SELECT_SCENARIO]
    .query("station in @stations_order")
    .rename(columns={"value_decade_mean": "value"})
    .copy()
)

decades = np.array(sorted(decadal_plot["decade"].unique()))
x = np.arange(len(decades))
bar_w = 0.22

# Okabe–Ito + Hatches
okabe_ito = {"St. Gallen": "#0072B2", "Bern": "#E69F00", "Sion": "#009E73"}
hatches   = {"St. Gallen": "////",    "Bern": "....",    "Sion": "xx"}

fig, ax = plt.subplots(figsize=(12, 4.8))

for i, st in enumerate(stations_order):
    sub = (
        decadal_plot[decadal_plot["station"] == st]
        .set_index("decade")
        .reindex(decades)["value"]
    )
    y = sub.to_numpy()
    off = (i - 1) * bar_w

    ax.bar(
        x + off, y, width=bar_w,
        color=okabe_ito.get(st, "#999999"),
        edgecolor="black", linewidth=0.7,
        hatch=hatches.get(st, ""), label=st
    )

    # optionale Werte-Labels
    for xi, yi in zip(x + off, y):
        if pd.notna(yi):
            ax.text(xi, yi, f"{yi:.1f}", ha="center", va="bottom", fontsize=8)

ax.set_xticks(x)
ax.set_xticklabels([str(d) for d in decades])
ax.set_ylabel("Decadal mean temperature (°C)")
ax.set_title(f"Decadal Mean Temperature – Side by Side ({SELECT_SCENARIO})")
ax.legend(ncol=len(stations_order), frameon=False)
ax.spines[["top", "right"]].set_visible(False)
ax.margins(x=0.02)
plt.tight_layout()
plt.show()


# ==============================================
# Faceted View
# ==============================================

# Globale Dekaden für alle Facets (gleiche X-Positionen)
all_decades = np.array(sorted(decadal["decade"].unique()))
xpos = np.arange(len(all_decades))

# Dynamische Ausdünnung der Ticklabels
if len(all_decades) <= 8:
    step = 1
elif len(all_decades) <= 12:
    step = 2
else:
    step = 3
tick_idx = np.arange(0, len(all_decades), step)
tick_labels = [str(d) for d in all_decades[tick_idx]]

cols = len(stations_order)
fig, axes = plt.subplots(1, cols, figsize=(max(11, 3.0*cols), 4.2), sharey=True)

for ax, st in zip(axes, stations_order):
    # Serie pro Station auf alle Dekaden alignen (fehlende -> NaN)
    sub = (
        decadal[decadal["station"] == st]
        .set_index("decade")
        .reindex(all_decades)["value"]
    )

    ax.bar(xpos, sub.values, color="#6e6e6e", edgecolor="black", linewidth=0.7)

    # Dezente Werte-Labels (optional)
    for xi, yi in zip(xpos, sub.values):
        if pd.notna(yi):
            ax.text(xi, yi, f"{yi:.1f}", ha="center", va="bottom", fontsize=8)

    ax.set_title(st)
    ax.spines[["top", "right"]].set_visible(False)
    ax.margins(x=0.02)

    # Feste Ticks & horizontal beschriftet, ausgedünnt
    ax.set_xticks(xpos[tick_idx])
    ax.set_xticklabels(tick_labels, rotation=0, ha="center", fontsize=9)
    ax.tick_params(axis="x", labelrotation=0, pad=2)

fig.supylabel("Decadal mean temperature (°C)")
fig.suptitle(f"Decadal Mean Temperature – Faceted View ({SELECT_SCENARIO})")
plt.tight_layout()
plt.show()

# %%
# ============================================
# Perioden & konsistente Bins
# ============================================
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Perioden definieren
P1 = (1991, 2020)
P2 = (2070, 2099)

df["year"] = df["date"].dt.year

df_use = df.copy()

d1 = df_use[(df_use["year"] >= P1[0]) & (df_use["year"] <= P1[1])]["value"].to_numpy()
d2 = df_use[(df_use["year"] >= P2[0]) & (df_use["year"] <= P2[1])]["value"].to_numpy()

# Gemeinsame Bin-Grenzen: gleiche Breite & Range für beide Verteilungen
bin_width = 0.5  # in °C (ggf. 0.25/1.0 anpassen)
lo = np.floor(min(d1.min(), d2.min()))
hi = np.ceil(max(d1.max(), d2.max()))
bins = np.arange(lo, hi + bin_width, bin_width)

# Okabe–Ito Farben (colour-blind safe)
c_old  = "#0072B2"  # blau
c_new  = "#E69F00"  # orange

# %%
# =========================================================
# Histogram: Transparent Overlay (Accessible)
# =========================================================
plt.figure(figsize=(9.5, 4.6))

# Transparenz + klare Kanten; gleiche Bins
plt.hist(d1, bins=bins, alpha=0.55, color=c_old,  edgecolor="black", linewidth=0.4, label=f"{P1[0]}–{P1[1]}")
plt.hist(d2, bins=bins, alpha=0.55, color=c_new,  edgecolor="black", linewidth=0.4, label=f"{P2[0]}–{P2[1]}")

# Optional: Density statt Frequency (kommentieren, falls gewünscht)
# plt.gca().set_ylabel("Density")

plt.title("Histogram – Transparent Overlay")
plt.xlabel("Temperature (°C)")
plt.ylabel("Frequency")
plt.legend(frameon=False)
plt.grid(True, axis="y", linewidth=0.4, alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# =========================================================
# Histogram: Side by Side
# =========================================================
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Daten d1 (1991–2020) und d2 (2070–2099) stammen aus dem vorherigen Setup
# Farben aus Okabe–Ito (colour-blind safe)
c_old = "#009E73"  # blau
c_new = "#E69F00"  # orange

# Sichtbaren Temperaturbereich definieren (Ausreißer schneiden)
p_lo = min(np.percentile(d1, 1), np.percentile(d2, 1))
p_hi = max(np.percentile(d1, 99), np.percentile(d2, 99))

# Binbreite (größer = ruhigeres Bild)
bin_width = 1.0  # in °C (bei Bedarf 0.5 wählen)
bins = np.arange(np.floor(p_lo), np.ceil(p_hi) + bin_width, bin_width)

# Zähle pro Bin und normiere auf Prozent
counts1, _ = np.histogram(d1, bins=bins)
counts2, _ = np.histogram(d2, bins=bins)
pct1 = counts1 / counts1.sum() * 100.0
pct2 = counts2 / counts2.sum() * 100.0

# X-Positionen (Bin-Mitten) und Balkenbreite
x_centers = (bins[:-1] + bins[1:]) / 2
w = (bins[1] - bins[0]) * 0.42  # etwas Abstand zwischen den Gruppen

fig, ax = plt.subplots(figsize=(18, 5))

# Balken: links alte Periode, rechts neue Periode
ax.bar(x_centers - w/2, pct1, width=w, color=c_old, edgecolor="black", linewidth=0.6,
       label="1991–2020", hatch="//")
ax.bar(x_centers + w/2, pct2, width=w, color=c_new, edgecolor="black", linewidth=0.6,
       label="2070–2099", hatch="....")

# Mittelwerte als Referenzlinien
m1 = np.mean(d1); m2 = np.mean(d2)
ax.axvline(m1, color=c_old, linestyle="--", linewidth=1.3, label=f"Mean 1991–2020: {m1:.1f}°C")
ax.axvline(m2, color=c_new, linestyle="--", linewidth=1.3, label=f"Mean 2070–2099: {m2:.1f}°C")

# Achsen & Gestaltung
ax.set_xlim(bins[0], bins[-1])
ax.set_xlabel("Temperature (°C)")
ax.set_ylabel("% of days")
ax.set_title("Histogram — Side by Side")
ax.grid(True, axis="y", linewidth=0.5, alpha=0.5)
ax.spines[["top", "right"]].set_visible(False)

# Legende in zwei Spalten: Perioden + Mittelwerte
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels, frameon=False, ncol=2)

plt.tight_layout()
plt.show()

# %%
# =========================================================
# Heatmaps
# =========================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

SELECT_SCENARIO = "RCP8.5"
STATIONS = ["Zürich", "Lugano"]
WINDOW_DAYS = 7
month_labels = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug",
                "Sep","Oct","Nov","Dec"]

# Daten vorbereiten
d = df[df["scenario"] == SELECT_SCENARIO].copy()
d["year"] = d["date"].dt.year
d["month"] = d["date"].dt.month
d["day"] = d["date"].dt.day
d["doy"] = d["date"].dt.dayofyear
d = d[~((d["month"] == 2) & (d["day"] == 29))]  # Schalttage entfernen

# Globale Farbskala
vmin = d["value"].min()
vmax = d["value"].max()

for st in STATIONS:
    ds = d[d["station"] == st]
    piv = (ds.pivot_table(index="year", columns="doy", values="value", aggfunc="mean")
             .sort_index())

    # Interpolieren & Glätten
    piv = piv.apply(lambda row: row.interpolate(limit_direction="both"), axis=1)
    piv_smooth = piv.apply(lambda row: row.rolling(WINDOW_DAYS, center=True, min_periods=1).mean(), axis=1)

    # Plot
    plt.figure(figsize=(12, 4))
    sns.heatmap(
        piv_smooth, cmap="RdBu_r", vmin=vmin, vmax=vmax,
        cbar=True, cbar_kws={"label": "Temperature (°C)"}
    )
    plt.title(f"Calendar Heatmap – {st} ({SELECT_SCENARIO})")

    # X-Achse: Monate
    n_days = piv_smooth.shape[1]
    ticks = np.linspace(0, n_days, 12, endpoint=False) + n_days/24
    plt.xticks(ticks, month_labels, rotation=0)
    plt.xlabel("Month")

    # Y-Achse: 20-Jahres-Schritte
    years_idx = piv_smooth.index.to_numpy()
    start = int(np.ceil(years_idx.min() / 20.0) * 20)
    end   = int(np.floor(years_idx.max() / 20.0) * 20)
    y_labels = np.arange(start, end + 1, 20)
    y_pos = [np.where(years_idx == y)[0][0] for y in y_labels if y in years_idx]

    plt.yticks(y_pos, [str(y) for y in np.array(y_labels)[np.isin(y_labels, years_idx)]], rotation=0)
    plt.ylabel("Year")

    plt.tight_layout()
    plt.show()
